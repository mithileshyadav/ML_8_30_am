# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Data/simple_lr_data.csv")
df
# Out:
#    Hours  Marks
# 0      1     35
# 1      2     40
# 2      3     50
# 3      4     65
# 4      5     70

# %%
plt.scatter(df["Hours"], df["Marks"])
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.title("Hours VS Marks")
plt.show()
