# %%
import pandas as pd
import numpy as np

# %%
student_data = pd.read_csv(r"E:\ML_Class_8_30_am\Data\Studnent_data.csv)
# Out:
#   Cell In[2], line 1
#     student_data = pd.read_csv("E:\ML_Class_8_30_am\Data\Studnent_data.csv)
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)
