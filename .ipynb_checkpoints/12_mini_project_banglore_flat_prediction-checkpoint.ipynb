# %%
import pandas as pd

# %%
df = pd.read_csv("Data/bangalore house price prediction.csv")
X = df.drop(columns= "price", axis = 1)    # indepent var
y = df["price"]   # output/dependent/target var

# %%
# train_test_split
from sklearn.model_selection import train_test_split
