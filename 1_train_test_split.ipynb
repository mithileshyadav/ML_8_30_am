# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
student_data = pd.read_csv(r"E:\ML_Class_8_30_am\Data\Studnent_data.csv")

# %%
# Read CSv DATA
student_data
# Out:
#   Student  पढ़ाई के घंटे (Hours) Tuition लिया (Yes/No)  \
# 0       A                      1                    No
# 1       B                      2                   Yes
# 2       C                      3                    No
# 3       D                      4                   Yes
# 4       E                      5                    No
# 5       F                      6                   Yes
# 6       G                      7                   Yes
# 7       H                      8                   Yes
# 8       I                      9                    No
# 9       J                     10                   Yes
#
#    Mobile इस्तेमाल (घंटे)  Attendance (%)  मार्क्स (Marks)
# 0                     5.0              60               10
# 1                     4.0              65               20
# 2                     6.0              70               30
# 3                     3.0              75               40
# 4                     2.0              80               50
# ...

# %%
# Feature/Independent (X)   and Target/Dependent variable (y) separate
X = student_data[["Student", "पढ़ाई के घंटे (Hours)", "Tuition लिया (Yes/No)", "Mobile इस्तेमाल (घंटे)", "Attendance (%)"]]

# %%
y = student_data["मार्क्स (Marks)"]

# %%
# 80 % data for train _train, y_tesand 20 % data for testing
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

# %%
# Check X_train and X_test data is 80% and 20% or not
print("Training Data: \n")
print(X_train.head(100))
# Out:
# Training Data:
#
#   Student  पढ़ाई के घंटे (Hours) Tuition लिया (Yes/No)  \
# 4       E                      5                    No
# 8       I                      9                    No
# 6       G                      7                   Yes
# 5       F                      6                   Yes
# 2       C                      3                    No
# 3       D                      4                   Yes
# 7       H                      8                   Yes
# 0       A                      1                    No
#
#    Mobile इस्तेमाल (घंटे)  Attendance (%)
# 4                     2.0              80
# 8                     2.0              94
# 6                     1.0              90
# 5                     1.5              85
# 2                     6.0              70
# 3                     3.0              75
# 7                     1.0              92
# 0                     5.0              60

# %%
print("Y traning data \n")
print(y_train)
# Out:
# Y traning data
#
# 4    50
# 8    90
# 6    70
# 5    60
# 2    30
# 3    40
# 7    80
# 0    10
# Name: मार्क्स (Marks), dtype: int64

# %%
print("X Testing data \n")
print(X_test)
# Out:
# X Testing data
#
#   Student  पढ़ाई के घंटे (Hours) Tuition लिया (Yes/No)  \
# 1       B                      2                   Yes
# 9       J                     10                   Yes
#
#    Mobile इस्तेमाल (घंटे)  Attendance (%)
# 1                     4.0              65
# 9                     0.5              95

# %%
print("Y test data \n")
print(y_test)
# Out:
# Y test data
#
# 1     20
# 9    100
# Name: मार्क्स (Marks), dtype: int64
